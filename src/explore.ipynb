# %% [markdown]
# # Explore here

# %%
# Your code here
import pandas as pd

movies_data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_movies.csv")
credits_data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_credits.csv")

# %% [markdown]
# note: since this is all cateogrical tokenised data dont scale it!

# %%
movies_data.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits_data.head(5)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %% [markdown]
# ### Join Using SQL

# %%
# Merge tables into one DataFrame
total_data = pd.merge(movies_data, credits_data, left_on=['id', 'title'], right_on=["movie_id", "title"])
total_data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
print(movies_data.shape)
print(credits_data.shape)
print(total_data.shape)
# Out:
# (4803, 20)
# (4803, 4)
# (4803, 23)

# %%
movies_data['title'].value_counts()
# Out:
# title
# The Host                 2
# Batman                   2
# Out of the Blue          2
# Avatar                   1
# The Girl on the Train    1
#                         ..
# Step Up 3D               1
# Secondhand Lions         1
# The Age of Adaline       1
# Drag Me to Hell          1
# My Date with Drew        1
# Name: count, Length: 4800, dtype: int64

# %%
mask_1 = movies_data['title'] == 'The Host' #, 'Batman', 'Out of the Blue'
movies_data[mask_1]
# Out:
#         budget                                             genres  \
# 972   44000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 2877  11000000  [{"id": 27, "name": "Horror"}, {"id": 18, "nam...
#
#                        homepage     id  \
# 972                         NaN  72710
# 2877  http://www.hostmovie.com/   1255
#
#                                                keywords original_language  \
# 972   [{"id": 818, "name": "based on novel"}, {"id":...                en
# 2877  [{"id": 1261, "name": "river"}, {"id": 1880, "...                ko
#
#      original_title                                           overview  \
# 972        The Host  A parasitic alien soul is injected into the bo...
# 2877             괴물  Gang-du is a dim-witted man working at his fat...
#
#       popularity                               production_companies  \
# 972    42.933027  [{"name": "Nick Wechsler Productions", "id": 8...
# ...

# %%
mask_2 = movies_data['title'] == 'Batman'
movies_data[mask_2]
# Out:
#         budget                                             genres homepage  \
# 1359  35000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...      NaN
# 4267   1377800  [{"id": 10751, "name": "Family"}, {"id": 12, "...      NaN
#
#         id                                           keywords  \
# 1359   268  [{"id": 848, "name": "double life"}, {"id": 84...
# 4267  2661  [{"id": 339, "name": "submarine"}, {"id": 849,...
#
#      original_language original_title  \
# 1359                en         Batman
# 4267                en         Batman
#
#                                                overview  popularity  \
# 1359  The Dark Knight of Gotham City begins his war ...   44.104469
# 4267  The Dynamic Duo faces four super-villains who ...    9.815394
#
#                                    production_companies  \
# 1359  [{"name": "PolyGram Filmed Entertainment", "id...
# 4267  [{"name": "Twentieth Century Fox Film Corporat...
#
# ...

# %%
mask_3 = movies_data['title'] == 'Out of the Blue'
movies_data[mask_3]
# Out:
#       budget                         genres homepage     id  \
# 3647       0  [{"id": 18, "name": "Drama"}]      NaN  39269
# 3693       0  [{"id": 18, "name": "Drama"}]      NaN  10844
#
#                                                keywords original_language  \
# 3647  [{"id": 4470, "name": "punk"}, {"id": 10183, "...                en
# 3693  [{"id": 2658, "name": "new zealand"}, {"id": 3...                en
#
#        original_title                                           overview  \
# 3647  Out of the Blue  Dennis Hopper is a hard-drinking truck driver ...
# 3693  Out of the Blue  Ordinary people find extraordinary courage in ...
#
#       popularity                      production_companies  \
# 3647    0.679351  [{"name": "Robson Street", "id": 71953}]
# 3693    0.706355                                        []
#
#                                production_countries release_date  revenue  \
# 3647       [{"iso_3166_1": "CA", "name": "Canada"}]   1980-05-01        0
# ...

# %% [markdown]
# ### Clean the generated table

# %%
# TODO: List the columns we want to keep in the following list, `columns_to_keep`
columns_to_keep = ["movie_id","title","overview","genres","keywords","cast","crew"]
total_data = total_data[columns_to_keep]
total_data.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %% [markdown]
# ### Transform the data

# %%
# Check the data type of `genres`, `keywords`, `cast`, `crew`
columns_to_check = ["genres", "keywords", "cast", "crew"]

for column in columns_to_check:
    print(f"Data type of the first row for column `{column}`: {type(total_data.loc[0, column])}")
# Out:
# Data type of the first row for column `genres`: <class 'str'>
# Data type of the first row for column `keywords`: <class 'str'>
# Data type of the first row for column `cast`: <class 'str'>
# Data type of the first row for column `crew`: <class 'str'>

# %%
import ast

# TODO: Convert string representation of lists to actual lists
total_data['genres'] = total_data['genres'].apply(ast.literal_eval)
total_data['keywords'] = total_data['keywords'].apply(ast.literal_eval)
total_data['cast'] = total_data['cast'].apply(ast.literal_eval)
total_data['crew'] = total_data['crew'].apply(ast.literal_eval)
# Verify that the data type was casted from a str to list
for column in columns_to_check:
    print(f"Data type of the first row for column `{column}`: {type(total_data.loc[0, column])}")
# Out:
# Data type of the first row for column `genres`: <class 'list'>
# Data type of the first row for column `keywords`: <class 'list'>
# Data type of the first row for column `cast`: <class 'list'>
# Data type of the first row for column `crew`: <class 'list'>

# %%
# TODO: Complete the `extract_name()` function to extract the 'name' attribute from the JSON
def extract_name(json_list):
    names = [item['name'] for item in json_list]
    return names

# Apply the `extract_name` function to 'genres' and 'keywords' columns
total_data['genres'] = total_data['genres'].apply(extract_name)
total_data['keywords'] = total_data['keywords'].apply(extract_name)

# TODO: Complete the `select_first_three_names()` function to select the first three names from the 'cast' column

def select_first_three_names(json_list):
    names = [item['name'] for item in json_list[:3]]
    return names
    

# Apply the `select_first_three_names` function to 'cast' column
total_data['cast'] = total_data['cast'].apply(select_first_three_names)

total_data.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
first_row_crew = total_data.loc[0, 'crew']

for dict_obj in first_row_crew:
    print(dict_obj)
    print()
# Out:
# {'credit_id': '52fe48009251416c750aca23', 'department': 'Editing', 'gender': 0, 'id': 1721, 'job': 'Editor', 'name': 'Stephen E. Rivkin'}
#
# {'credit_id': '539c47ecc3a36810e3001f87', 'department': 'Art', 'gender': 2, 'id': 496, 'job': 'Production Design', 'name': 'Rick Carter'}
#
# {'credit_id': '54491c89c3a3680fb4001cf7', 'department': 'Sound', 'gender': 0, 'id': 900, 'job': 'Sound Designer', 'name': 'Christopher Boyes'}
#
# {'credit_id': '54491cb70e0a267480001bd0', 'department': 'Sound', 'gender': 0, 'id': 900, 'job': 'Supervising Sound Editor', 'name': 'Christopher Boyes'}
#
# {'credit_id': '539c4a4cc3a36810c9002101', 'department': 'Production', 'gender': 1, 'id': 1262, 'job': 'Casting', 'name': 'Mali Finn'}
#
# {'credit_id': '5544ee3b925141499f0008fc', 'department': 'Sound', 'gender': 2, 'id': 1729, 'job': 'Original Music Composer', 'name': 'James Horner'}
#
# ...

# %%
# Define the select_director_name function to select the director's name from the crew list
def select_director_name(json_list):
    name = ''
    # Go through each dictionary in list to find the director's name
    for dict_obj in json_list:
        if dict_obj["job"] == "Director":
            name = dict_obj["name"]
    return name

# Apply the select_director_name function to 'crew' column
total_data['crew'] = total_data['crew'].apply(select_director_name)

total_data.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# Convert the 'genres', 'keywords', and 'cast' columns to strings without adding separators between elements
# Convert the 'genres', 'keywords', and 'cast' columns to strings without adding separators between elements
total_data['genres'] = total_data['genres'].apply(lambda x: ''.join(map(str, x)))
total_data['keywords'] = total_data['keywords'].apply(lambda x: ''.join(map(str, x)))
total_data['cast'] = total_data['cast'].apply(lambda x: ''.join(map(str, x)))

total_data.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                   genres  \
# 0  ActionAdventureFantasyScience Fiction
# 1                 AdventureFantasyAction
# 2                   ActionAdventureCrime
# 3               ActionCrimeDramaThriller
# 4         ActionAdventureScience Fiction
#
#                                             keywords  \
# ...

# %%
total_data[total_data.isnull().any(axis=1)]
# Out:
#       movie_id                                       title overview  \
# 2656    370980  Chiamatemi Francesco - Il Papa della gente      NaN
# 4140    459488                 To Be Frank, Sinatra at 100      NaN
# 4431    292539                                 Food Chains      NaN
#
#            genres                                           keywords  \
# 2656        Drama                                      popebiography
# 4140  Documentary  musicactorslegendary perfomerclassic hollywood...
# 4431  Documentary
#
#                                                    cast               crew
# 2656  Rodrigo de la SernaSergio HernándezÀlex Brende...   Daniele Luchetti
# 4140                                    Tony Oppedisano  Simon Napier-Bell
# 4431                                                          Sanjay Rawal

# %%
# fill missing value with string
total_data.fillna('', inplace=True)

# %%
# Combine the columns into a single column called 'tags'
total_data['tags'] = total_data.apply(lambda row: ''.join(row['overview']) + '' + ''.join(row['genres']) + '' + ''.join(row['keywords']) + '' + ''.join(row['cast']), axis=1)

# Print the 'tags' column for the first row
print(total_data.iloc[0].tags)

# Display the updated dataframe
total_data.head()
# Out:
# In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.ActionAdventureFantasyScience Fictionculture clashfuturespace warspace colonysocietyspace travelfuturisticromancespacealientribealien planetcgimarinesoldierbattlelove affairanti warpower relationsmind and soul3dSam WorthingtonZoe SaldanaSigourney Weaver
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# ...

# %% [markdown]
# Vectorizing

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english')
vectorized_tags = vectorizer.fit_transform(total_data['tags'].values.astype('U'))

print (vectorized_tags)
# Out:
#   (0, 48446)	0.1748660102159655
#   (0, 39988)	0.2140926204233082
#   (0, 49471)	0.2140926204233082
#   (0, 42541)	0.2140926204233082
#   (0, 38243)	0.20421027477607387
#   (0, 48174)	0.2140926204233082
#   (0, 1849)	0.2140926204233082
#   (0, 35547)	0.2140926204233082
#   (0, 46100)	0.2140926204233082
#   (0, 9212)	0.2140926204233082
#   (0, 48212)	0.2140926204233082
#   (0, 8738)	0.2140926204233082
#   (0, 18609)	0.2140926204233082
#   (0, 818)	0.18355919986218824
#   (0, 8676)	0.17254302823381398
#   (0, 2323)	0.1307928352140885
#   (0, 36649)	0.16666521839320328
#   (0, 33821)	0.15922219319858583
#   (0, 19773)	0.13515675328082596
#   (0, 45714)	0.1480896830997462
#   (0, 31119)	0.11161222205050454
#   (0, 46861)	0.1515774603979366
#   (0, 34311)	0.18030465748533825
#   (0, 31405)	0.16341067601635326
#   (0, 14211)	0.1748660102159655
#   :	:
#   (4802, 11984)	0.1385451710629854
#   (4802, 26059)	0.13964159458288547
#   (4802, 40221)	0.158131409800209
# ...

# %% [markdown]
# ### Fitting Model

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(vectorized_tags)

# Define the recommend function
def recommend(movie):
    movie_index = total_data[total_data["title"] == movie].index[0]
    distances = similarity[movie_index]
    movie_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:6]
    
    recommended_movies = [total_data.iloc[i[0]]['title'] for i in movie_list]
    return recommended_movies

# Example usage
recommended_movies = recommend("Avatar")
print("Recommended movies for Avatar:", recommended_movies)
# Out:
# Recommended movies for Avatar: ['Apollo 18', 'The American', 'Turbulence', 'Tears of the Sun', 'The Inhabited Island']
